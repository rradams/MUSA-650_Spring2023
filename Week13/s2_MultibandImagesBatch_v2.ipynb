# %% [markdown]
# ## Example for batch processing of images
# How to select RGB bands from a set of multiband images in a folder

# %%
import numpy as np
import os
import skimage.io as skio
import matplotlib.pyplot as plt
import pandas as pd
from glob import glob
import imageio

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Functions

# %%
def select_rgb_bands_from_multiband(f_in, f_out, rgb_bands = [3, 2, 1], 
                                    crop_min_perc = 0.5, crop_max_perc = 99.5):
    ## Read input multiband image
    mat_in = skio.imread(f_in, plugin="tifffile")
    
    ## Select bands
    mat_out = mat_in[:,:, [3, 2, 1]]
    
    ## Scale img in each band (using percentiles, as it's more robust to outliers)
    for i in [0, 1, 2]:
        scmin = np.percentile(mat_out[:, :, i], crop_min_perc)
        scmax = np.percentile(mat_out[:, :, i], crop_max_perc)
        delta = scmax - scmin
        mat_out[:, :, i] = ((mat_out[:, :, i] - scmin) / delta * 255).astype(int)
        
    ## Crop values that are out of range (defined by percentiles)
    mat_out[mat_out < 0] = 0
    mat_out[mat_out > 255] = 255

    ## Create output folder
    try:
        out_dir = os.path.dirname(f_out)
        if os.path.exists(out_dir) == False :
            os.makedirs(out_dir)
    except:
        print('Error creating output folder, skip image')
        return;
    
    ## Save image
    try:
        imageio.imsave(f_out, mat_out.astype(np.uint8))    
    except:
        print('Error writing output image, skip image')
        return;

# %% [markdown]
# #### Read list of images

# %%
## Find all images
#indir = '../inputs/'
indir = '/content/drive/MyDrive/CommonFiles/MUSA650-Data/Prj_EuroSat'

f_all_mb = os.path.join(indir, 'data_small', 'multiband', '*/*.tif')
in_img_list = glob(f_all_mb)

## Save to dataframe
df_in = pd.DataFrame(data = in_img_list, columns = ['FileName'])

# %%
df_in.head()
# Out:
#                                             FileName
# 0  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 1  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 2  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 3  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 4  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...

# %%
df_in.loc[0].FileName
# Out:
# '/content/drive/MyDrive/CommonFiles/MUSA650-Data/Prj_EuroSat/data_small/multiband/AnnualCrop/AnnualCrop_241.tif'

# %%
## Detect categories
df_in['Category'] = df_in.FileName.str.split(os.sep).str[9]
df_in.groupby('Category').count()
# Out:
#              FileName
# Category
# AnnualCrop         50
# Industrial         50
# Residential        50

# %%
## Detect image names
df_in['ImageName'] = df_in.FileName.str.split(os.sep).str[10].str.replace('.tif', '', regex = False)
df_in = df_in[['ImageName', 'Category', 'FileName']]
df_in.head()
# Out:
#          ImageName    Category  \
# 0   AnnualCrop_241  AnnualCrop
# 1  AnnualCrop_1528  AnnualCrop
# 2  AnnualCrop_1891  AnnualCrop
# 3   AnnualCrop_465  AnnualCrop
# 4   AnnualCrop_233  AnnualCrop
#
#                                             FileName
# 0  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 1  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 2  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 3  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...
# 4  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...

# %%
df_in['ImageIndex'] = df_in.ImageName.str.split('_').str[1].astype(int)

# %%
df_in.head()
# Out:
#          ImageName    Category  \
# 0   AnnualCrop_241  AnnualCrop
# 1  AnnualCrop_1528  AnnualCrop
# 2  AnnualCrop_1891  AnnualCrop
# 3   AnnualCrop_465  AnnualCrop
# 4   AnnualCrop_233  AnnualCrop
#
#                                             FileName  ImageIndex
# 0  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...         241
# 1  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...        1528
# 2  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...        1891
# 3  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...         465
# 4  /content/drive/MyDrive/CommonFiles/MUSA650-Dat...         233

# %% [markdown]
# #### Extract RGB bands from all images

# %%
#outdir = '../outputs/bands_rgb'
outdir = '/content/drive/MyDrive/CommonFiles/MUSA650-Data/Prj_EuroSat/outclassrun'

for i, tmp_ind in enumerate(df_in.index):
    tmp_name = df_in.loc[tmp_ind, 'ImageName']
    tmp_cat = df_in.loc[tmp_ind, 'Category']
    tmp_file = df_in.loc[tmp_ind, 'FileName']
    print('Extracting RGB bands from image ' + str(i) + ' : ' + tmp_name)
    f_out = os.path.join(outdir, tmp_cat, tmp_name + '_my_rgb.png')
    select_rgb_bands_from_multiband(tmp_file, f_out)
    
    ## input('Enter a key to continue')   ## For testing the initial run
# Out:
# Extracting RGB bands from image 0 : AnnualCrop_241
# Extracting RGB bands from image 1 : AnnualCrop_1528
# Extracting RGB bands from image 2 : AnnualCrop_1891
# Extracting RGB bands from image 3 : AnnualCrop_465
# Extracting RGB bands from image 4 : AnnualCrop_233
# Extracting RGB bands from image 5 : AnnualCrop_621
# Extracting RGB bands from image 6 : AnnualCrop_68
# Extracting RGB bands from image 7 : AnnualCrop_255
# Extracting RGB bands from image 8 : AnnualCrop_2544
# Extracting RGB bands from image 9 : AnnualCrop_1943
# Extracting RGB bands from image 10 : AnnualCrop_1744
# Extracting RGB bands from image 11 : AnnualCrop_119
# Extracting RGB bands from image 12 : AnnualCrop_1432
# Extracting RGB bands from image 13 : AnnualCrop_2844
# Extracting RGB bands from image 14 : AnnualCrop_1775
# Extracting RGB bands from image 15 : AnnualCrop_659
# Extracting RGB bands from image 16 : AnnualCrop_1375
# Extracting RGB bands from image 17 : AnnualCrop_2417
# Extracting RGB bands from image 18 : AnnualCrop_230
# Extracting RGB bands from image 19 : AnnualCrop_1367
# Extracting RGB bands from image 20 : AnnualCrop_2684
# Extracting RGB bands from image 21 : AnnualCrop_1633
# Extracting RGB bands from image 22 : AnnualCrop_2833
# Extracting RGB bands from image 23 : AnnualCrop_1007
# Extracting RGB bands from image 24 : AnnualCrop_4
# Extracting RGB bands from image 25 : AnnualCrop_1279
# Extracting RGB bands from image 26 : AnnualCrop_1017
# Extracting RGB bands from image 27 : AnnualCrop_1806
# Extracting RGB bands from image 28 : AnnualCrop_2160
# Extracting RGB bands from image 29 : AnnualCrop_1867
# Extracting RGB bands from image 30 : AnnualCrop_2375
# Extracting RGB bands from image 31 : AnnualCrop_1435
# Extracting RGB bands from image 32 : AnnualCrop_2809
# Extracting RGB bands from image 33 : AnnualCrop_1644
# Extracting RGB bands from image 34 : AnnualCrop_2995
# Extracting RGB bands from image 35 : AnnualCrop_2269
# Extracting RGB bands from image 36 : AnnualCrop_130
# Extracting RGB bands from image 37 : AnnualCrop_2638
# Extracting RGB bands from image 38 : AnnualCrop_2679
# Extracting RGB bands from image 39 : AnnualCrop_1648
# Extracting RGB bands from image 40 : AnnualCrop_10
# Extracting RGB bands from image 41 : AnnualCrop_944
# Extracting RGB bands from image 42 : AnnualCrop_787
# Extracting RGB bands from image 43 : AnnualCrop_99
# Extracting RGB bands from image 44 : AnnualCrop_1780
# Extracting RGB bands from image 45 : AnnualCrop_2004
# Extracting RGB bands from image 46 : AnnualCrop_109
# Extracting RGB bands from image 47 : AnnualCrop_544
# Extracting RGB bands from image 48 : AnnualCrop_557
# Extracting RGB bands from image 49 : AnnualCrop_1343
# Extracting RGB bands from image 50 : Residential_339
# Extracting RGB bands from image 51 : Residential_795
# Extracting RGB bands from image 52 : Residential_2963
# Extracting RGB bands from image 53 : Residential_1543
# Extracting RGB bands from image 54 : Residential_829
# Extracting RGB bands from image 55 : Residential_1641
# Extracting RGB bands from image 56 : Residential_647
# Extracting RGB bands from image 57 : Residential_2898
# Extracting RGB bands from image 58 : Residential_2158
# Extracting RGB bands from image 59 : Residential_2498
# Extracting RGB bands from image 60 : Residential_882
# Extracting RGB bands from image 61 : Residential_1669
# Extracting RGB bands from image 62 : Residential_1038
# Extracting RGB bands from image 63 : Residential_754
# Extracting RGB bands from image 64 : Residential_461
# Extracting RGB bands from image 65 : Residential_1053
# Extracting RGB bands from image 66 : Residential_1662
# Extracting RGB bands from image 67 : Residential_862
# Extracting RGB bands from image 68 : Residential_769
# Extracting RGB bands from image 69 : Residential_324
# Extracting RGB bands from image 70 : Residential_1784
# Extracting RGB bands from image 71 : Residential_1982
# Extracting RGB bands from image 72 : Residential_1932
# Extracting RGB bands from image 73 : Residential_1715
# Extracting RGB bands from image 74 : Residential_2589
# Extracting RGB bands from image 75 : Residential_1268
# Extracting RGB bands from image 76 : Residential_171
# Extracting RGB bands from image 77 : Residential_377
# Extracting RGB bands from image 78 : Residential_126
# Extracting RGB bands from image 79 : Residential_867
# Extracting RGB bands from image 80 : Residential_1713
# Extracting RGB bands from image 81 : Residential_1503
# Extracting RGB bands from image 82 : Residential_1410
# Extracting RGB bands from image 83 : Residential_524
# Extracting RGB bands from image 84 : Residential_596
# Extracting RGB bands from image 85 : Residential_1462
# Extracting RGB bands from image 86 : Residential_728
# Extracting RGB bands from image 87 : Residential_580
# Extracting RGB bands from image 88 : Residential_2218
# Extracting RGB bands from image 89 : Residential_2274
# Extracting RGB bands from image 90 : Residential_759
# Extracting RGB bands from image 91 : Residential_1508
# Extracting RGB bands from image 92 : Residential_247
# Extracting RGB bands from image 93 : Residential_1929
# Extracting RGB bands from image 94 : Residential_207
# Extracting RGB bands from image 95 : Residential_275
# Extracting RGB bands from image 96 : Residential_2092
# Extracting RGB bands from image 97 : Residential_1248
# Extracting RGB bands from image 98 : Residential_1643
# Extracting RGB bands from image 99 : Residential_2869
# Extracting RGB bands from image 100 : Industrial_760
# Extracting RGB bands from image 101 : Industrial_1079
# Extracting RGB bands from image 102 : Industrial_1229
# Extracting RGB bands from image 103 : Industrial_1784
# Extracting RGB bands from image 104 : Industrial_1109
# Extracting RGB bands from image 105 : Industrial_840
# Extracting RGB bands from image 106 : Industrial_1255
# Extracting RGB bands from image 107 : Industrial_1885
# Extracting RGB bands from image 108 : Industrial_167
# Extracting RGB bands from image 109 : Industrial_990
# Extracting RGB bands from image 110 : Industrial_890
# Extracting RGB bands from image 111 : Industrial_157
# Extracting RGB bands from image 112 : Industrial_1501
# Extracting RGB bands from image 113 : Industrial_1301
# Extracting RGB bands from image 114 : Industrial_1560
# Extracting RGB bands from image 115 : Industrial_486
# Extracting RGB bands from image 116 : Industrial_326
# Extracting RGB bands from image 117 : Industrial_1272
# Extracting RGB bands from image 118 : Industrial_1362
# Extracting RGB bands from image 119 : Industrial_1082
# Extracting RGB bands from image 120 : Industrial_82
# Extracting RGB bands from image 121 : Industrial_2264
# Extracting RGB bands from image 122 : Industrial_2193
# Extracting RGB bands from image 123 : Industrial_297
# Extracting RGB bands from image 124 : Industrial_1438
# Extracting RGB bands from image 125 : Industrial_228
# Extracting RGB bands from image 126 : Industrial_76
# Extracting RGB bands from image 127 : Industrial_190
# Extracting RGB bands from image 128 : Industrial_1352
# Extracting RGB bands from image 129 : Industrial_950
# Extracting RGB bands from image 130 : Industrial_804
# Extracting RGB bands from image 131 : Industrial_901
# Extracting RGB bands from image 132 : Industrial_506
# Extracting RGB bands from image 133 : Industrial_621
# Extracting RGB bands from image 134 : Industrial_303
# Extracting RGB bands from image 135 : Industrial_120
# Extracting RGB bands from image 136 : Industrial_650
# Extracting RGB bands from image 137 : Industrial_379
# Extracting RGB bands from image 138 : Industrial_532
# Extracting RGB bands from image 139 : Industrial_1899
# Extracting RGB bands from image 140 : Industrial_1905
# Extracting RGB bands from image 141 : Industrial_480
# Extracting RGB bands from image 142 : Industrial_866
# Extracting RGB bands from image 143 : Industrial_1853
# Extracting RGB bands from image 144 : Industrial_1966
# Extracting RGB bands from image 145 : Industrial_2282
# Extracting RGB bands from image 146 : Industrial_545
# Extracting RGB bands from image 147 : Industrial_1378
# Extracting RGB bands from image 148 : Industrial_2443
# Extracting RGB bands from image 149 : Industrial_1797
